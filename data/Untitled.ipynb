# %%
import pandas as pd
df = pd.read_csv (r'/Users/anushika/Desktop/COLLEGE/AP/Inhibition-of-Return-/data/10_experiment_2020_Apr_18_1922.csv')
print (df)
# Out:
#                         image_cue_1            image_cue_2  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2             images/light_grey_box  images/light_grey_box
# 3             images/light_grey_box  images/light_grey_box
# 4    images/light_grey_box_with_cue  images/light_grey_box
# ..                              ...                    ...
# 118  images/light_grey_box_with_cue  images/light_grey_box
# 119  images/light_grey_box_with_cue  images/light_grey_box
# 120           images/light_grey_box  images/light_grey_box
# 121           images/light_grey_box  images/light_grey_box
# 122                             NaN                    NaN
#
#                         image_cue_3         image_target_1  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2             images/light_grey_box  images/light_grey_box
# ...

# %%
sum_cue=[0,0,0,0,0,0] # 0.0, 0.05, 0.1, 0.2, 0.3, 0.5
sum_un=[0,0,0,0,0,0]
sum_cen=[0,0,0,0,0,0]
ctr=0
ctr_cue=[0,0,0,0,0,0] # 0.0, 0.05, 0.1, 0.2, 0.3, 0.5
ctr_un=[0,0,0,0,0,0]
ctr_cen=[0,0,0,0,0,0]
ctr_n=0

for index, row in df.iterrows():
    if ((index >1) & (index <122)):
        cue=0
        targ=0
        j=-1
        strt=row['startTime']
        if(strt==0.0):
            j=0
        if(strt==0.05):
            j=1
        if(strt==0.1):
            j=2
        if(strt==0.2):
            j=3
        if(strt==0.3):
            j=4
        if(strt==0.5):
            j=5

        if (row['image_cue_1']=='images/light_grey_box_with_cue'):
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_cue[j]+=row['keyResponse.rt']
                ctr_cue[j]+=1

            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1

            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        elif (row['image_cue_3']=='images/light_grey_box_with_cue'):
                if(row['image_target_3']=='images/light_grey_box_with_target'):
                    sum_cue[j]+=row['keyResponse.rt']
                    ctr_cue[j]+=1

                elif (row['image_target_1']=='images/light_grey_box_with_target'):
                    sum_un[j]+=row['keyResponse.rt']
                    ctr_un[j]+=1

                elif (row['image_target_2']=='images/light_grey_box_with_target'):
                    sum_cen[j]+=row['keyResponse.rt']
                    ctr_cen[j]+=1
                else:
                    ctr_n+=1
        else:
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        

print(sum_cue)
print(sum_un)
print(sum_cen)
print(ctr_cue)
print(ctr_cen)
print(ctr_un)
print(ctr_n)
# Out:
# [1.4525481480000053, 2.590260920999981, 2.488265082999988, 2.0354868750000605, 0.33152038399987305, 0.29179806700005884]
# [0.39450697500012666, 0.1938789270000143, 0.13149702700002308, 0.07893171300008818, 0.15291532100002314, 0.1663870089998909]
# [7.721089573999279, 4.119534680000243, 4.578269199000147, 6.476914529000055, 6.839551262999862, 3.702820866000593]
# [2, 2, 2, 2, 2, 2]
# [12, 13, 13, 13, 13, 13]
# [2, 1, 1, 1, 1, 1]
# 24

# %%
df1 = pd.read_csv (r'/Users/anushika/Desktop/COLLEGE/AP/Inhibition-of-Return-/data/1_experiment_2020_Apr_15_1901.csv')

for index, row in df1.iterrows():
    if ((index >1) & (index <122)):
        cue=0
        targ=0
        j=-1
        strt=row['startTime']
        if(strt==0.0):
            j=0
        if(strt==0.05):
            j=1
        if(strt==0.1):
            j=2
        if(strt==0.2):
            j=3
        if(strt==0.3):
            j=4
        if(strt==0.5):
            j=5

        if (row['image_cue_1']=='images/light_grey_box_with_cue'):
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_cue[j]+=row['keyResponse.rt']
                ctr_cue[j]+=1

            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1

            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        elif (row['image_cue_3']=='images/light_grey_box_with_cue'):
                if(row['image_target_3']=='images/light_grey_box_with_target'):
                    sum_cue[j]+=row['keyResponse.rt']
                    ctr_cue[j]+=1

                elif (row['image_target_1']=='images/light_grey_box_with_target'):
                    sum_un[j]+=row['keyResponse.rt']
                    ctr_un[j]+=1

                elif (row['image_target_2']=='images/light_grey_box_with_target'):
                    sum_cen[j]+=row['keyResponse.rt']
                    ctr_cen[j]+=1
                else:
                    ctr_n+=1
        else:
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        

print(sum_cue)
print(sum_un)
print(sum_cen)
print(ctr_cue)
print(ctr_cen)
print(ctr_un)
print(ctr_n)
# Out:
# [1.9463742480206747, 3.1662100209625805, 3.0898733829994858, 2.369958974959445, 0.9402067839952224, 0.6146036670662625]
# [1.3316649750735223, 0.33543922696230766, 0.42392202699238624, 0.28814171300098224, 0.543640720949611, 0.6040020090024427]
# [10.984058774091181, 8.691107279932794, 8.243052398958184, 10.929533629047796, 9.581825462961547, 7.382363866064452]
# [4, 4, 4, 4, 4, 4]
# [24, 26, 26, 26, 26, 26]
# [4, 2, 2, 2, 2, 2]
# 48

# %%
df1 = pd.read_csv (r'/Users/anushika/Desktop/COLLEGE/AP/Inhibition-of-Return-/data/2_experiment_2020_Apr_15_1916.csv')

for index, row in df1.iterrows():
    if ((index >1) & (index <122)):
        cue=0
        targ=0
        j=-1
        strt=row['startTime']
        if(strt==0.0):
            j=0
        if(strt==0.05):
            j=1
        if(strt==0.1):
            j=2
        if(strt==0.2):
            j=3
        if(strt==0.3):
            j=4
        if(strt==0.5):
            j=5

        if (row['image_cue_1']=='images/light_grey_box_with_cue'):
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_cue[j]+=row['keyResponse.rt']
                ctr_cue[j]+=1

            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1

            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        elif (row['image_cue_3']=='images/light_grey_box_with_cue'):
                if(row['image_target_3']=='images/light_grey_box_with_target'):
                    sum_cue[j]+=row['keyResponse.rt']
                    ctr_cue[j]+=1

                elif (row['image_target_1']=='images/light_grey_box_with_target'):
                    sum_un[j]+=row['keyResponse.rt']
                    ctr_un[j]+=1

                elif (row['image_target_2']=='images/light_grey_box_with_target'):
                    sum_cen[j]+=row['keyResponse.rt']
                    ctr_cen[j]+=1
                else:
                    ctr_n+=1
        else:
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        

print(sum_cue)
print(sum_un)
print(sum_cen)
print(ctr_cue)
print(ctr_cen)
print(ctr_un)
print(ctr_n)
# Out:
# [6.682773148006618, 3.878315120947491, 3.9056777829569005, 3.30109957496461, 1.574522884035673, 1.6579779670111066]
# [1.8812702750832386, 0.6644692269849202, 1.132877826978529, 0.6192480130010836, 1.2243511209386497, 0.8904424090017073]
# [18.9743608740539, 17.41572487996632, 12.851425198952143, 21.219190628976207, 18.313229662866775, 17.418637066071142]
# [6, 6, 6, 6, 6, 6]
# [36, 39, 39, 39, 39, 39]
# [6, 3, 3, 3, 3, 3]
# 72

# %%
df1 = pd.read_csv (r'/Users/anushika/Desktop/COLLEGE/AP/Inhibition-of-Return-/data/3_experiment_2020_Apr_15_1924.csv')

for index, row in df1.iterrows():
    if ((index >1) & (index <122)):
        cue=0
        targ=0
        j=-1
        strt=row['startTime']
        if(strt==0.0):
            j=0
        if(strt==0.05):
            j=1
        if(strt==0.1):
            j=2
        if(strt==0.2):
            j=3
        if(strt==0.3):
            j=4
        if(strt==0.5):
            j=5

        if (row['image_cue_1']=='images/light_grey_box_with_cue'):
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_cue[j]+=row['keyResponse.rt']
                ctr_cue[j]+=1

            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1

            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        elif (row['image_cue_3']=='images/light_grey_box_with_cue'):
                if(row['image_target_3']=='images/light_grey_box_with_target'):
                    sum_cue[j]+=row['keyResponse.rt']
                    ctr_cue[j]+=1

                elif (row['image_target_1']=='images/light_grey_box_with_target'):
                    sum_un[j]+=row['keyResponse.rt']
                    ctr_un[j]+=1

                elif (row['image_target_2']=='images/light_grey_box_with_target'):
                    sum_cen[j]+=row['keyResponse.rt']
                    ctr_cen[j]+=1
                else:
                    ctr_n+=1
        else:
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        

print(sum_cue)
print(sum_un)
print(sum_cen)
print(ctr_cue)
print(ctr_cen)
print(ctr_un)
print(ctr_n)
# Out:
# [8.030978248053088, 6.419150120881795, 4.4738090829373505, 3.9765466749231564, 2.1742074840555006, 2.2083233670101663]
# [2.5343449751193248, 6.506541426956801, 1.436523927023245, 3.1860843129578593, 1.5215235209331013, 1.080489808957509]
# [27.866212674082135, 21.265906980049067, 16.534235798867826, 31.036105029003807, 29.9420344629674, 21.454388466179125]
# [8, 8, 8, 8, 8, 8]
# [48, 52, 52, 52, 52, 52]
# [8, 4, 4, 4, 4, 4]
# 96

# %%
df1 = pd.read_csv (r'/Users/anushika/Desktop/COLLEGE/AP/Inhibition-of-Return-/data/4_experiment_2020_Apr_15_1931.csv')

for index, row in df1.iterrows():
    if ((index >1) & (index <122)):
        cue=0
        targ=0
        j=-1
        strt=row['startTime']
        if(strt==0.0):
            j=0
        if(strt==0.05):
            j=1
        if(strt==0.1):
            j=2
        if(strt==0.2):
            j=3
        if(strt==0.3):
            j=4
        if(strt==0.5):
            j=5

        if (row['image_cue_1']=='images/light_grey_box_with_cue'):
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_cue[j]+=row['keyResponse.rt']
                ctr_cue[j]+=1

            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1

            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        elif (row['image_cue_3']=='images/light_grey_box_with_cue'):
                if(row['image_target_3']=='images/light_grey_box_with_target'):
                    sum_cue[j]+=row['keyResponse.rt']
                    ctr_cue[j]+=1

                elif (row['image_target_1']=='images/light_grey_box_with_target'):
                    sum_un[j]+=row['keyResponse.rt']
                    ctr_un[j]+=1

                elif (row['image_target_2']=='images/light_grey_box_with_target'):
                    sum_cen[j]+=row['keyResponse.rt']
                    ctr_cen[j]+=1
                else:
                    ctr_n+=1
        else:
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        

print(sum_cue)
print(sum_un)
print(sum_cen)
print(ctr_cue)
print(ctr_cen)
print(ctr_un)
print(ctr_n)
# Out:
#
df1 = pd.read_csv (r'/Users/anushika/Desktop/COLLEGE/AP/Inhibition-of-Return-/data/akash_experiment_2020_Apr_18_2103.csv')

for index, row in df1.iterrows():
    if ((index >1) & (index <122)):
        cue=0
        targ=0
        j=-1
        strt=row['startTime']
        if(strt==0.0):
            j=0
        if(strt==0.05):
            j=1
        if(strt==0.1):
            j=2
        if(strt==0.2):
            j=3
        if(strt==0.3):
            j=4
        if(strt==0.5):
            j=5

        if (row['image_cue_1']=='images/light_grey_box_with_cue'):
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_cue[j]+=row['keyResponse.rt']
                ctr_cue[j]+=1

            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1

            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        elif (row['image_cue_3']=='images/light_grey_box_with_cue'):
                if(row['image_target_3']=='images/light_grey_box_with_target'):
                    sum_cue[j]+=row['keyResponse.rt']
                    ctr_cue[j]+=1

                elif (row['image_target_1']=='images/light_grey_box_with_target'):
                    sum_un[j]+=row['keyResponse.rt']
                    ctr_un[j]+=1

                elif (row['image_target_2']=='images/light_grey_box_with_target'):
                    sum_cen[j]+=row['keyResponse.rt']
                    ctr_cen[j]+=1
                else:
                    ctr_n+=1
        else:
            if(row['image_target_1']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_3']=='images/light_grey_box_with_target'):
                sum_un[j]+=row['keyResponse.rt']
                ctr_un[j]+=1
                
            elif (row['image_target_2']=='images/light_grey_box_with_target'):
                sum_cen[j]+=row['keyResponse.rt']
                ctr_cen[j]+=1
            else:
                ctr_n+=1

        

print(sum_cue)
print(sum_un)
print(sum_cen)
print(ctr_cue)
print(ctr_cen)
print(ctr_un)
print(ctr_n)
# Out:
# [12.301829895027765, 10.768834737823454, 9.315203915922552, 8.409022424870614, 7.130163542095659, 6.283103147205736]
# [9.331592096093033, 8.371249200902696, 3.1464756251268113, 5.454937800988375, 2.9073384948732155, 2.8646523690416643]
# [50.953809998264035, 69.89020154921565, 68.48232232196389, 62.66442246092498, 78.73407238038172, 92.24058755426191]
# [22, 22, 22, 22, 22, 22]
# [132, 143, 143, 143, 143, 143]
# [22, 11, 11, 11, 11, 11]
# 264

# %%
import numpy as np

sum_cue=np.array(sum_cue, dtype=np.float)
sum_cen=np.array(sum_cen, dtype=np.float)
sum_un=np.array(sum_un, dtype=np.float)

ctr_un=np.array(ctr_un, dtype=np.int)
ctr_cen=np.array(ctr_cen, dtype=np.int)
ctr_cue=np.array(ctr_cue, dtype=np.int)

avg_cue=sum_cue/ctr_cue
avg_un=sum_un/ctr_un
avg_cen=sum_cen/ctr_cen

print(avg_cue)
print(avg_un)
print(avg_cen)
# Out:
# [0.55917409 0.48949249 0.42341836 0.38222829 0.32409834 0.2855956 ]
# [0.42416328 0.76102265 0.28604324 0.49590344 0.2643035  0.26042294]
# [0.38601371 0.48874267 0.47889736 0.43821274 0.55058792 0.64503907]

# %%
import matplotlib.pyplot as plt 

x=[0.0,0.05,0.1,0.2,0.3,0.5]
plt.plot(x, avg_cue, color='green', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='green', markersize=10)
plt.plot(x, avg_un, color='red', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='red', markersize=10)
plt.plot(x, avg_cen, color='yellow', linestyle='dashed', linewidth = 3, marker='o', markerfacecolor='yellow', markersize=10)

plt.ylim(0,1) 
plt.xlim(-0.1,0.7) 

plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 

plt.title('Some cool customizations!')
# Out:
# Text(0.5, 1.0, 'Some cool customizations!')
